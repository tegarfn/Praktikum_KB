# %% [markdown]
# <h1><b>POSTTEST 3</b></h1>
# <h2>Kecerdasan buatan</h2>
# <p>Nama : Tegar Fitrah Naba Atthoriq<br>NIM : 2009106085</p>

# %% [markdown]
# <h2><b>Visualisasi Data</b></h2>
#
# <p>memanggil package dan dataset</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv('tv_shows.csv')
ds
# Out:
#       Unnamed: 0    ID                                  Title  Year  Age  \
# 0              0     1                           Breaking Bad  2008  18+
# 1              1     2                        Stranger Things  2016  16+
# 2              2     3                        Attack on Titan  2013  18+
# 3              3     4                       Better Call Saul  2015  18+
# 4              4     5                                   Dark  2017  16+
# ...          ...   ...                                    ...   ...  ...
# 5363        5363  5713                       Paradise Islands  2017  NaN
# 5364        5364  5714                         Mexico Untamed  2018  NaN
# 5365        5365  5715                  Wild Centeral America  2020  NaN
# 5366        5366  5716                            Wild Russia  2018  NaN
# 5367        5367  5717  Fearless Adventures with Jack Randall  2018  NaN
#
#         IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# ...

# %% [markdown]
# <p>mengecek dataset</p>

# %%
ds.dtypes
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5368 entries, 0 to 5367
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       5368 non-null   int64
#  1   ID               5368 non-null   int64
#  2   Title            5368 non-null   object
#  3   Year             5368 non-null   int64
#  4   Age              3241 non-null   object
#  5   IMDb             4406 non-null   object
#  6   Rotten Tomatoes  5368 non-null   object
#  7   Netflix          5368 non-null   int64
#  8   Hulu             5368 non-null   int64
#  9   Prime Video      5368 non-null   int64
#  10  Disney+          5368 non-null   int64
#  11  Type             5368 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 503.4+ KB
#       Unnamed: 0    ID                                  Title  Year  Age  \
# 0              0     1                           Breaking Bad  2008  18+
# ...

# %% [markdown]
# <h3><b>Membuat Grafik Batang</b></h3>
# <p>
#     untuk membut grafik batang, menggunakan fungsi 'plt.bar()', carannya sebagai berikut:
# </p>
# <ol>
#     <li>memanggil fungsi plt.bar()</li>
#     <li>fungsi diisi dengan data pertama untuk line X, data kedua untuk line Y, dan warna grafiknya</li>
#     <li>berikan label grafik, label Y, dan label Y</li>
# </ol>
# <h4><b>Hasil</b></h4>
# <p>
#     dari hasil visualisasi data, didapat bahwa film dengan rating 'all' paling banyak tampil di platform film <br>
#     rating '13+' mulai muncul di tahun 90-an hingga sekarang<br>
# </p>

# %%
ds.dropna(inplace=True)

plt.bar(ds['Year'], ds['Age'], color='red')
plt.title('Rating berdasarkan Tahun Rilis', loc='center')
plt.xlabel('Tahun')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# <h3><b>Membuat Scatter Plot</b></h3>
# <p>
#     untuk membut scatter plot, menggunakan fungsi 'sns.scatterplot()', carannya sebagai berikut:
# </p>
# <ol>
#     <li>memanggil fungsi sns.scatterplot()</li>
#     <li>fungsi diisi dengan atrbut 'Year' untuk line X, atribut 'IMDb' untuk line Y</li>
# </ol>
# <h4><b>Hasil</b></h4>
# <p>
#     dari hasil visualisasi data, didapat bahwa rating IMDb mulai banyak digunakan sejak film tahun 90-an
# </p>

# %%
sns.scatterplot(data = ds, x = "Year", y = "IMDb")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h3><b>Membuat Pie Chart</b></h3>
# <p>
#     untuk membuat pie cart, menggunakan fungsi 'plt.pie()', carannya sebagai berikut:
# </p>
# <ol>
#     <li>memanggil fungsi plt.pie()</li>
#     <li>fungsi diisi dengan dataset, label, posisi awal mulai lingkaran, dan jumlah angka dibelakang koma</li>
#     <li>memberikan title chart</li>
#     <li>membuat legenda tentang keterangan pie chart</li>
# </ol>
# <h4><b>Hasil</b></h4>
# <p>
#     dari hasil visualisasi data, didapat bahwa rating '16+' memiliki presentase paling besar yaitu sebesar 30.8%, disusul rating '18+' sebesar 26.6%, dan seterusnya. persentase terkecil didapat oleh rating '13+' yaitu 0.3%
# </p>

# %%
dc = ds.dropna(subset=['Age'])

pc = dc['Age'].value_counts().rename_axis('Age').reset_index(name='Id_count')
plt.figure(figsize=(5,5))
plt.pie(pc.Id_count, labels=pc.Age, startangle=90, autopct='%.1f%%')
plt.title('Persentase Rating')
plt.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.show()
